# %%
import mysql.connector as conn

# %%
mysql_py=conn.connect(host='localhost',user='root',password='python')

# %%
mysql_py #connection done

# %%
cursor=mysql_py.cursor() #cursor created

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('ineuron',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testdb',),
#  ('testdbs',),
#  ('world',)]

# %%
cursor.execute('select * from testdb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute('select c1,c3,c5,c11 from testdb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 13.64, 1.1, 1),
#  (2, 13.89, 1.36, 1),
#  (3, 13.53, 1.54, 1),
#  (4, 13.21, 1.29, 1),
#  (6, 12.79, 1.62, 1),
#  (7, 13.3, 1.14, 1),
#  (8, 13.15, 1.05, 1),
#  (9, 14.04, 1.37, 1),
#  (10, 13.0, 1.36, 1),
#  (11, 12.72, 1.56, 1),
#  (12, 12.8, 1.27, 1),
#  (14, 12.86, 1.27, 1),
#  (15, 12.61, 1.31, 1),
#  (16, 12.81, 1.23, 1),
#  (17, 12.68, 1.16, 1),
#  (18, 14.36, 0.89, 1),
#  (19, 13.9, 1.18, 1),
#  (20, 13.02, 1.69, 1),
#  (21, 12.82, 1.49, 1),
#  (22, 14.77, 0.29, 1),
#  (23, 12.78, 1.29, 1),
#  (24, 12.81, 1.35, 1),
#  (25, 13.38, 1.15, 1),
#  (26, 12.98, 1.21, 1),
#  (27, 13.21, 1.41, 1),
#  (28, 12.87, 1.33, 1),
#  (29, 12.56, 1.43, 1),
#  (30, 13.08, 1.28, 1),
#  (31, 12.65, 1.3, 1),
#  (32, 12.84, 1.14, 1),
#  (33, 12.85, 1.23, 1),
#  (34, 12.57, 1.38, 1),
#  (35, 12.69, 1.34, 1),
#  (36, 13.29, 1.21, 1),
#  (37, 13.89, 1.32, 1),
#  (38, 12.74, 1.35, 1),
#  (39, 14.21, 0.47, 1),
#  (40, 14.21, 0.47, 1),
#  (41, 12.79, 1.12, 1),
#  (42, 12.71, 1.2, 1),
# ...

# %%
cursor.execute("delete from testdb.glassdata where c1='9'")

# %%
cursor.execute('select * from testdb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
cursor.execute('select * from testdb.glassdata where c11=7')

# %%
cursor.fetchall()
# Out:
# [(186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (187, 1.51838, 14.32, 3.26, 2.22, 71.25, 1.46, 5.79, 1.63, 0.0, 7),
#  (188, 1.52315, 13.44, 3.34, 1.23, 72.38, 0.6, 8.83, 0.0, 0.0, 7),
#  (189, 1.52247, 14.86, 2.2, 2.06, 70.26, 0.76, 9.76, 0.0, 0.0, 7),
#  (190, 1.52365, 15.79, 1.83, 1.31, 70.43, 0.31, 8.61, 1.68, 0.0, 7),
#  (191, 1.51613, 13.88, 1.78, 1.79, 73.1, 0.0, 8.67, 0.76, 0.0, 7),
#  (192, 1.51602, 14.85, 0.0, 2.38, 73.28, 0.0, 8.76, 0.64, 0.09, 7),
#  (193, 1.51623, 14.2, 0.0, 2.79, 73.46, 0.04, 9.04, 0.4, 0.09, 7),
#  (194, 1.51719, 14.75, 0.0, 2.0, 73.02, 0.0, 8.53, 1.59, 0.08, 7),
#  (195, 1.51683, 14.56, 0.0, 1.98, 73.29, 0.0, 8.52, 1.57, 0.07, 7),
#  (196, 1.51545, 14.14, 0.0, 2.68, 73.39, 0.08, 9.07, 0.61, 0.05, 7),
#  (197, 1.51556, 13.87, 0.0, 2.54, 73.23, 0.14, 9.41, 0.81, 0.01, 7),
#  (198, 1.51727, 14.7, 0.0, 2.34, 73.28, 0.0, 8.95, 0.66, 0.0, 7),
#  (199, 1.51531, 14.38, 0.0, 2.66, 73.1, 0.04, 9.08, 0.64, 0.0, 7),
# ...

# %%
cursor.execute('select * from testdb.glassdata where c1 between 180 and 190 and c9=0')

# %%
cursor.fetchall()
# Out:
# [(180, 1.51852, 14.09, 2.19, 1.66, 72.67, 0.0, 9.32, 0.0, 0.0, 6),
#  (181, 1.51299, 14.4, 1.74, 1.54, 74.55, 0.0, 7.59, 0.0, 0.0, 6),
#  (182, 1.51888, 14.99, 0.78, 1.74, 72.5, 0.0, 9.95, 0.0, 0.0, 6),
#  (183, 1.51916, 14.15, 0.0, 2.09, 72.74, 0.0, 10.88, 0.0, 0.0, 6),
#  (184, 1.51969, 14.56, 0.0, 0.56, 73.48, 0.0, 11.22, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (188, 1.52315, 13.44, 3.34, 1.23, 72.38, 0.6, 8.83, 0.0, 0.0, 7),
#  (189, 1.52247, 14.86, 2.2, 2.06, 70.26, 0.76, 9.76, 0.0, 0.0, 7),
#  (180, 1.51852, 14.09, 2.19, 1.66, 72.67, 0.0, 9.32, 0.0, 0.0, 6),
#  (181, 1.51299, 14.4, 1.74, 1.54, 74.55, 0.0, 7.59, 0.0, 0.0, 6),
#  (182, 1.51888, 14.99, 0.78, 1.74, 72.5, 0.0, 9.95, 0.0, 0.0, 6),
#  (183, 1.51916, 14.15, 0.0, 2.09, 72.74, 0.0, 10.88, 0.0, 0.0, 6),
#  (184, 1.51969, 14.56, 0.0, 0.56, 73.48, 0.0, 11.22, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
# ...

# %%
cursor.execute("UPDATE testdb.glassdata SET c1='7' and c2='7.77' WHERE c1='22'")

# %%
cursor.execute('select * from testdb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (0, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("delete from testdb.glassdata where c1='0'")

# %%
cursor.execute('select * from testdb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (20, 1.51735, 13.02, 3.54, 1.69, 72.73, 0.54, 8.44, 0.0, 0.07, 1),
# ...

# %%
cursor.execute('update testdb.glassdata set c1=7 and c2 = 3.3 where c1=29')

# %%
cursor.execute('select * from testdb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute('select c1,c2 from testdb.glassdata group by c1' )

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101),
#  (2, 1.51761),
#  (3, 1.51618),
#  (4, 1.51766),
#  (6, 1.51596),
#  (7, 1.51743),
#  (8, 1.51756),
#  (9, 1.51918),
#  (10, 1.51755),
#  (11, 1.51571),
#  (12, 1.51763),
#  (14, 1.51748),
#  (15, 1.51763),
#  (16, 1.51761),
#  (17, 1.51784),
#  (18, 1.52196),
#  (20, 1.51735),
#  (21, 1.5175),
#  (22, 1.51966),
#  (23, 1.51736),
#  (24, 1.51751),
#  (25, 1.5172),
#  (26, 1.51764),
#  (27, 1.51793),
#  (28, 1.51721),
#  (29, 1.51768),
#  (30, 1.51784),
#  (31, 1.51768),
#  (32, 1.51747),
#  (33, 1.51775),
#  (34, 1.51753),
#  (35, 1.51783),
#  (36, 1.51567),
#  (37, 1.51909),
#  (38, 1.51797),
#  (39, 1.52213),
#  (40, 1.52213),
#  (41, 1.51793),
#  (42, 1.51755),
#  (43, 1.51779),
#  (44, 1.5221),
#  (45, 1.51786),
#  (46, 1.519),
#  (47, 1.51869),
#  (48, 1.52667),
#  (49, 1.52223),
#  (50, 1.51898),
#  (51, 1.5232),
#  (52, 1.51926),
#  (53, 1.51808),
#  (54, 1.51837),
#  (55, 1.51778),
#  (56, 1.51769),
#  (57, 1.51215),
#  (58, 1.51824),
#  (59, 1.51754),
# ...

# %%
cursor.execute('select count(c1),c1,c2 from testdb.glassdata group by c1' )

# %%
cursor.fetchall()
# Out:
# [(8, 1, 1.52101),
#  (7, 2, 1.51761),
#  (7, 3, 1.51618),
#  (7, 4, 1.51766),
#  (7, 6, 1.51596),
#  (7, 7, 1.51743),
#  (7, 8, 1.51756),
#  (7, 9, 1.51918),
#  (7, 10, 1.51755),
#  (7, 11, 1.51571),
#  (7, 12, 1.51763),
#  (7, 14, 1.51748),
#  (7, 15, 1.51763),
#  (7, 16, 1.51761),
#  (7, 17, 1.51784),
#  (7, 18, 1.52196),
#  (7, 20, 1.51735),
#  (7, 21, 1.5175),
#  (7, 22, 1.51966),
#  (7, 23, 1.51736),
#  (7, 24, 1.51751),
#  (7, 25, 1.5172),
#  (7, 26, 1.51764),
#  (7, 27, 1.51793),
#  (7, 28, 1.51721),
#  (7, 29, 1.51768),
#  (7, 30, 1.51784),
#  (7, 31, 1.51768),
#  (7, 32, 1.51747),
#  (7, 33, 1.51775),
#  (7, 34, 1.51753),
#  (7, 35, 1.51783),
#  (7, 36, 1.51567),
#  (7, 37, 1.51909),
#  (7, 38, 1.51797),
#  (7, 39, 1.52213),
#  (7, 40, 1.52213),
#  (7, 41, 1.51793),
#  (7, 42, 1.51755),
#  (7, 43, 1.51779),
#  (7, 44, 1.5221),
#  (7, 45, 1.51786),
#  (7, 46, 1.519),
#  (7, 47, 1.51869),
#  (7, 48, 1.52667),
#  (7, 49, 1.52223),
#  (7, 50, 1.51898),
#  (7, 51, 1.5232),
# ...

# %%
cursor.execute('select count(*),c1,c2 from testdb.glassdata group by c1' )

# %%
cursor.fetchall()
# Out:
# [(8, 1, 1.52101),
#  (7, 2, 1.51761),
#  (7, 3, 1.51618),
#  (7, 4, 1.51766),
#  (7, 6, 1.51596),
#  (7, 7, 1.51743),
#  (7, 8, 1.51756),
#  (7, 9, 1.51918),
#  (7, 10, 1.51755),
#  (7, 11, 1.51571),
#  (7, 12, 1.51763),
#  (7, 14, 1.51748),
#  (7, 15, 1.51763),
#  (7, 16, 1.51761),
#  (7, 17, 1.51784),
#  (7, 18, 1.52196),
#  (7, 20, 1.51735),
#  (7, 21, 1.5175),
#  (7, 22, 1.51966),
#  (7, 23, 1.51736),
#  (7, 24, 1.51751),
#  (7, 25, 1.5172),
#  (7, 26, 1.51764),
#  (7, 27, 1.51793),
#  (7, 28, 1.51721),
#  (7, 29, 1.51768),
#  (7, 30, 1.51784),
#  (7, 31, 1.51768),
#  (7, 32, 1.51747),
#  (7, 33, 1.51775),
#  (7, 34, 1.51753),
#  (7, 35, 1.51783),
#  (7, 36, 1.51567),
#  (7, 37, 1.51909),
#  (7, 38, 1.51797),
#  (7, 39, 1.52213),
#  (7, 40, 1.52213),
#  (7, 41, 1.51793),
#  (7, 42, 1.51755),
#  (7, 43, 1.51779),
#  (7, 44, 1.5221),
#  (7, 45, 1.51786),
#  (7, 46, 1.519),
#  (7, 47, 1.51869),
#  (7, 48, 1.52667),
#  (7, 49, 1.52223),
#  (7, 50, 1.51898),
#  (7, 51, 1.5232),
# ...

# %%
cursor.execute('select count(c1),c1,c2 from testdb.glassdata group by c1 order by c1 desc' )

# %%
cursor.fetchall()
# Out:
# [(7, 214, 1.51711),
#  (7, 213, 1.51651),
#  (7, 212, 1.52065),
#  (7, 211, 1.51685),
#  (7, 210, 1.51623),
#  (7, 209, 1.5164),
#  (7, 208, 1.51831),
#  (7, 207, 1.51645),
#  (7, 206, 1.51732),
#  (7, 205, 1.51617),
#  (7, 204, 1.51658),
#  (7, 203, 1.51514),
#  (7, 202, 1.51653),
#  (7, 201, 1.51508),
#  (7, 200, 1.51609),
#  (7, 199, 1.51531),
#  (7, 198, 1.51727),
#  (7, 197, 1.51556),
#  (7, 196, 1.51545),
#  (7, 195, 1.51683),
#  (7, 194, 1.51719),
#  (7, 193, 1.51623),
#  (7, 192, 1.51602),
#  (7, 191, 1.51613),
#  (7, 190, 1.52365),
#  (7, 189, 1.52247),
#  (7, 188, 1.52315),
#  (7, 187, 1.51838),
#  (7, 186, 1.51131),
#  (7, 185, 1.51115),
#  (7, 184, 1.51969),
#  (7, 183, 1.51916),
#  (7, 182, 1.51888),
#  (7, 181, 1.51299),
#  (7, 180, 1.51852),
#  (7, 179, 1.51829),
#  (7, 178, 1.51937),
#  (7, 177, 1.51905),
#  (7, 176, 1.52119),
#  (7, 175, 1.52058),
#  (7, 174, 1.52043),
#  (7, 173, 1.51321),
#  (7, 172, 1.51316),
#  (7, 171, 1.52369),
#  (7, 170, 1.51994),
# ...

# %%
cursor.execute('select count(c1),c1,c2 from testdb.glassdata group by c1 order by count(c1) desc' )

# %%
cursor.fetchall()
# Out:
# [(8, 1, 1.52101),
#  (7, 2, 1.51761),
#  (7, 3, 1.51618),
#  (7, 4, 1.51766),
#  (7, 6, 1.51596),
#  (7, 7, 1.51743),
#  (7, 8, 1.51756),
#  (7, 9, 1.51918),
#  (7, 10, 1.51755),
#  (7, 11, 1.51571),
#  (7, 12, 1.51763),
#  (7, 14, 1.51748),
#  (7, 15, 1.51763),
#  (7, 16, 1.51761),
#  (7, 17, 1.51784),
#  (7, 18, 1.52196),
#  (7, 20, 1.51735),
#  (7, 21, 1.5175),
#  (7, 22, 1.51966),
#  (7, 23, 1.51736),
#  (7, 24, 1.51751),
#  (7, 25, 1.5172),
#  (7, 26, 1.51764),
#  (7, 27, 1.51793),
#  (7, 28, 1.51721),
#  (7, 29, 1.51768),
#  (7, 30, 1.51784),
#  (7, 31, 1.51768),
#  (7, 32, 1.51747),
#  (7, 33, 1.51775),
#  (7, 34, 1.51753),
#  (7, 35, 1.51783),
#  (7, 36, 1.51567),
#  (7, 37, 1.51909),
#  (7, 38, 1.51797),
#  (7, 39, 1.52213),
#  (7, 40, 1.52213),
#  (7, 41, 1.51793),
#  (7, 42, 1.51755),
#  (7, 43, 1.51779),
#  (7, 44, 1.5221),
#  (7, 45, 1.51786),
#  (7, 46, 1.519),
#  (7, 47, 1.51869),
#  (7, 48, 1.52667),
#  (7, 49, 1.52223),
#  (7, 50, 1.51898),
#  (7, 51, 1.5232),
# ...

# %%
cursor.execute('select count(c1),c1,c2,c11,count(c11) from testdb.glassdata group by c1 order by count(c11) desc' )

# %%
cursor.fetchall()
# Out:
# [(8, 1, 1.52101, 1, 8),
#  (7, 2, 1.51761, 1, 7),
#  (7, 3, 1.51618, 1, 7),
#  (7, 4, 1.51766, 1, 7),
#  (7, 6, 1.51596, 1, 7),
#  (7, 7, 1.51743, 1, 7),
#  (7, 8, 1.51756, 1, 7),
#  (7, 9, 1.51918, 1, 7),
#  (7, 10, 1.51755, 1, 7),
#  (7, 11, 1.51571, 1, 7),
#  (7, 12, 1.51763, 1, 7),
#  (7, 14, 1.51748, 1, 7),
#  (7, 15, 1.51763, 1, 7),
#  (7, 16, 1.51761, 1, 7),
#  (7, 17, 1.51784, 1, 7),
#  (7, 18, 1.52196, 1, 7),
#  (7, 20, 1.51735, 1, 7),
#  (7, 21, 1.5175, 1, 7),
#  (7, 22, 1.51966, 1, 7),
#  (7, 23, 1.51736, 1, 7),
#  (7, 24, 1.51751, 1, 7),
#  (7, 25, 1.5172, 1, 7),
#  (7, 26, 1.51764, 1, 7),
#  (7, 27, 1.51793, 1, 7),
#  (7, 28, 1.51721, 1, 7),
#  (7, 29, 1.51768, 1, 7),
#  (7, 30, 1.51784, 1, 7),
#  (7, 31, 1.51768, 1, 7),
#  (7, 32, 1.51747, 1, 7),
#  (7, 33, 1.51775, 1, 7),
#  (7, 34, 1.51753, 1, 7),
#  (7, 35, 1.51783, 1, 7),
#  (7, 36, 1.51567, 1, 7),
#  (7, 37, 1.51909, 1, 7),
#  (7, 38, 1.51797, 1, 7),
#  (7, 39, 1.52213, 1, 7),
#  (7, 40, 1.52213, 1, 7),
# ...

# %%
cursor.execute('select count(c1),c1,c2 from testdb.glassdata group by c1 order by c2 ' )

# %%
cursor.fetchall()
# Out:
# [(7, 185, 1.51115),
#  (7, 186, 1.51131),
#  (7, 57, 1.51215),
#  (7, 181, 1.51299),
#  (7, 172, 1.51316),
#  (7, 173, 1.51321),
#  (7, 85, 1.51409),
#  (7, 201, 1.51508),
#  (7, 164, 1.51514),
#  (7, 203, 1.51514),
#  (7, 199, 1.51531),
#  (7, 196, 1.51545),
#  (7, 197, 1.51556),
#  (7, 36, 1.51567),
#  (7, 87, 1.51569),
#  (7, 11, 1.51571),
#  (7, 71, 1.51574),
#  (7, 93, 1.51588),
#  (7, 76, 1.5159),
#  (7, 80, 1.5159),
#  (7, 94, 1.5159),
#  (7, 81, 1.51592),
#  (7, 73, 1.51593),
#  (7, 82, 1.51593),
#  (7, 84, 1.51594),
#  (7, 6, 1.51596),
#  (7, 75, 1.51596),
#  (7, 192, 1.51602),
#  (7, 92, 1.51605),
#  (7, 200, 1.51609),
#  (7, 148, 1.5161),
#  (7, 154, 1.5161),
#  (7, 79, 1.51613),
#  (7, 191, 1.51613),
#  (7, 205, 1.51617),
#  (7, 3, 1.51618),
#  (7, 89, 1.51618),
#  (7, 193, 1.51623),
#  (7, 210, 1.51623),
#  (7, 86, 1.51625),
#  (7, 78, 1.51627),
#  (7, 95, 1.51629),
#  (7, 74, 1.51631),
#  (7, 90, 1.5164),
#  (7, 209, 1.5164),
#  (7, 150, 1.51643),
#  (7, 77, 1.51645),
# ...

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('ineuron',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testdb',),
#  ('testdbs',),
#  ('world',)]

# %%
cursor.execute('use testdb')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('table1',)]

# %%
cursor.execute('drop table testdb.table1')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',)]

# %%
cursor.execute('use testdbs')
cursor.execute('create table testdbs.newtable(c1 INT(5), c2 VARCHAR(15),c3 INT(10))')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('newtable',)]

# %%
mysql_py.commit()

# %%
cursor.execute('use testdb')
cursor.execute('create table testdb.extratable(c1 INT(5), c2 VARCHAR(15),c3 INT(10))')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('extratable',), ('glassdata',)]

# %%
mysql_py.commit()

# %% [markdown]
#  create database
#
# create table
#
# insert single /bulk record
#
# delete
#
# update
#
# groupby
#
# where
#
# orderby

# %%
cursor.execute('select c1,c2,c11 from testdb.glassdata where c1=21 or c11=2')

# %%
cursor.fetchall()
# Out:
# [(21, 1.5175, 1),
#  (71, 1.51574, 2),
#  (72, 1.51848, 2),
#  (73, 1.51593, 2),
#  (74, 1.51631, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (77, 1.51645, 2),
#  (78, 1.51627, 2),
#  (79, 1.51613, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (83, 1.51646, 2),
#  (84, 1.51594, 2),
#  (85, 1.51409, 2),
#  (86, 1.51625, 2),
#  (87, 1.51569, 2),
#  (88, 1.51645, 2),
#  (89, 1.51618, 2),
#  (90, 1.5164, 2),
#  (91, 1.51841, 2),
#  (92, 1.51605, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (95, 1.51629, 2),
#  (96, 1.5186, 2),
#  (97, 1.51841, 2),
#  (98, 1.51743, 2),
#  (99, 1.51689, 2),
#  (100, 1.51811, 2),
#  (101, 1.51655, 2),
#  (102, 1.5173, 2),
#  (103, 1.5182, 2),
#  (104, 1.52725, 2),
#  (105, 1.5241, 2),
#  (106, 1.52475, 2),
#  (107, 1.53125, 2),
#  (108, 1.53393, 2),
#  (109, 1.52222, 2),
#  (110, 1.51818, 2),
#  (111, 1.52664, 2),
#  (112, 1.52739, 2),
#  (113, 1.52777, 2),
#  (114, 1.51892, 2),
#  (115, 1.51847, 2),
#  (116, 1.51846, 2),
# ...

# %%
cursor.execute('select c1,c2,c11 from testdb.glassdata where c1=21 and c11=2')
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select c1,c2,c11 from testdb.glassdata where c2 like '1.515%'") # % regex place holder-zero or more
#_- regex place holder only one

# %%
cursor.fetchall()
# Out:
# [(6, 1.51596, 1),
#  (11, 1.51571, 1),
#  (36, 1.51567, 1),
#  (71, 1.51574, 2),
#  (73, 1.51593, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (84, 1.51594, 2),
#  (87, 1.51569, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (164, 1.51514, 5),
#  (196, 1.51545, 7),
#  (197, 1.51556, 7),
#  (199, 1.51531, 7),
#  (201, 1.51508, 7),
#  (203, 1.51514, 7),
#  (6, 1.51596, 1),
#  (11, 1.51571, 1),
#  (36, 1.51567, 1),
#  (71, 1.51574, 2),
#  (73, 1.51593, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (84, 1.51594, 2),
#  (87, 1.51569, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (164, 1.51514, 5),
#  (196, 1.51545, 7),
#  (197, 1.51556, 7),
#  (199, 1.51531, 7),
#  (201, 1.51508, 7),
#  (203, 1.51514, 7),
#  (6, 1.51596, 1),
#  (11, 1.51571, 1),
#  (36, 1.51567, 1),
#  (71, 1.51574, 2),
#  (73, 1.51593, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
# ...

# %%
cursor.execute('select * from testdb.glassdata order by c2 ' )

# %%
cursor.fetchall()
# Out:
# [(185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
# ...

# %%
cursor.execute("select * from testdb.glassdata where c1>112")

# %%
cursor.fetchall()
# Out:
# [(113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (114, 1.51892, 13.46, 3.83, 1.26, 72.55, 0.57, 8.21, 0.0, 0.14, 2),
#  (115, 1.51847, 13.1, 3.97, 1.19, 72.44, 0.6, 8.43, 0.0, 0.0, 2),
#  (116, 1.51846, 13.41, 3.89, 1.33, 72.38, 0.51, 8.28, 0.0, 0.0, 2),
#  (117, 1.51829, 13.24, 3.9, 1.41, 72.33, 0.55, 8.31, 0.0, 0.1, 2),
#  (118, 1.51708, 13.72, 3.68, 1.81, 72.06, 0.64, 7.88, 0.0, 0.0, 2),
#  (119, 1.51673, 13.3, 3.64, 1.53, 72.53, 0.65, 8.03, 0.0, 0.29, 2),
#  (120, 1.51652, 13.56, 3.57, 1.47, 72.45, 0.64, 7.96, 0.0, 0.0, 2),
#  (121, 1.51844, 13.25, 3.76, 1.32, 72.4, 0.58, 8.42, 0.0, 0.0, 2),
#  (122, 1.51663, 12.93, 3.54, 1.62, 72.96, 0.64, 8.03, 0.0, 0.21, 2),
#  (123, 1.51687, 13.23, 3.54, 1.48, 72.84, 0.56, 8.1, 0.0, 0.0, 2),
#  (124, 1.51707, 13.48, 3.48, 1.71, 72.52, 0.62, 7.99, 0.0, 0.0, 2),
#  (125, 1.52177, 13.2, 3.68, 1.15, 72.75, 0.54, 8.52, 0.0, 0.0, 2),
#  (126, 1.51872, 12.93, 3.66, 1.56, 72.51, 0.58, 8.55, 0.0, 0.12, 2),
# ...

# %%
cursor.execute("select * from (select * from testdb.glassdata where c1>'112') as internaltable where c11= '3'")#subquery

# %%
cursor.fetchall()
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...

# %%
cursor.execute("select * from testdb.glassdata group by c1 ")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute('select * from testdb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testdb.glassdata group by c1 having count(c1)>7")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %%
cursor.execute('create database cardataset')

# %%
cursor.execute('create table cardataset.cars(buying VARCHAR(10),maint VARCHAR(10),doors VARCHAR(10),persons VARCHAR(10),lug_boot VARCHAR(10),safety VARCHAR(10),speed VARCHAR(10))')

# %%
cursor.execute('use cardataset')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('car',), ('cars',)]

# %%
x= open('car.data','r')
x.read()
# Out:
# 'vhigh,vhigh,2,2,small,low,unacc\nvhigh,vhigh,2,2,small,med,unacc\nvhigh,vhigh,2,2,small,high,unacc\nvhigh,vhigh,2,2,med,low,unacc\nvhigh,vhigh,2,2,med,med,unacc\nvhigh,vhigh,2,2,med,high,unacc\nvhigh,vhigh,2,2,big,low,unacc\nvhigh,vhigh,2,2,big,med,unacc\nvhigh,vhigh,2,2,big,high,unacc\nvhigh,vhigh,2,4,small,low,unacc\nvhigh,vhigh,2,4,small,med,unacc\nvhigh,vhigh,2,4,small,high,unacc\nvhigh,vhigh,2,4,med,low,unacc\nvhigh,vhigh,2,4,med,med,unacc\nvhigh,vhigh,2,4,med,high,unacc\nvhigh,vhigh,2,4,big,low,unacc\nvhigh,vhigh,2,4,big,med,unacc\nvhigh,vhigh,2,4,big,high,unacc\nvhigh,vhigh,2,more,small,low,unacc\nvhigh,vhigh,2,more,small,med,unacc\nvhigh,vhigh,2,more,small,high,unacc\nvhigh,vhigh,2,more,med,low,unacc\nvhigh,vhigh,2,more,med,med,unacc\nvhigh,vhigh,2,more,med,high,unacc\nvhigh,vhigh,2,more,big,low,unacc\nvhigh,vhigh,2,more,big,med,unacc\nvhigh,vhigh,2,more,big,high,unacc\nvhigh,vhigh,3,2,small,low,unacc\nvhigh,vhigh,3,2,small,med,unacc\nvhigh,vhigh,3,2,small,high,unacc\nvhigh,
# ...

# %%
x.seek(0)
x.readlines()
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc\n',
#  'vhigh,vhigh,2,2,small,med,unacc\n',
#  'vhigh,vhigh,2,2,small,high,unacc\n',
#  'vhigh,vhigh,2,2,med,low,unacc\n',
#  'vhigh,vhigh,2,2,med,med,unacc\n',
#  'vhigh,vhigh,2,2,med,high,unacc\n',
#  'vhigh,vhigh,2,2,big,low,unacc\n',
#  'vhigh,vhigh,2,2,big,med,unacc\n',
#  'vhigh,vhigh,2,2,big,high,unacc\n',
#  'vhigh,vhigh,2,4,small,low,unacc\n',
#  'vhigh,vhigh,2,4,small,med,unacc\n',
#  'vhigh,vhigh,2,4,small,high,unacc\n',
#  'vhigh,vhigh,2,4,med,low,unacc\n',
#  'vhigh,vhigh,2,4,med,med,unacc\n',
#  'vhigh,vhigh,2,4,med,high,unacc\n',
#  'vhigh,vhigh,2,4,big,low,unacc\n',
#  'vhigh,vhigh,2,4,big,med,unacc\n',
#  'vhigh,vhigh,2,4,big,high,unacc\n',
#  'vhigh,vhigh,2,more,small,low,unacc\n',
#  'vhigh,vhigh,2,more,small,med,unacc\n',
#  'vhigh,vhigh,2,more,small,high,unacc\n',
#  'vhigh,vhigh,2,more,med,low,unacc\n',
#  'vhigh,vhigh,2,more,med,med,unacc\n',
#  'vhigh,vhigh,2,more,med,high,unacc\n',
#  'vhigh,vhigh,2,more,big,low,unacc\n',
# ...

# %%
import csv
with open('car.data','r') as f:
    car_data=csv.reader(f,delimiter=',')
    car_data_list=list(car_data)
car_data_list
            
cursor.executemany('insert into cardataset.cars values(%s,%s,%s,%s,%s,%s,%s)',car_data_list)

# %%
cursor.execute('select count(*) from cardataset.cars')

# %%
cursor.fetchall()
# Out:
# [(1728,)]

# %%
mysql_py.commit()

# %%
cursor.execute('select * from cardataset.cars')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
import pandas as pd
pd.read_sql('select * from cardataset.cars',mysql_py)
# Out:
#      buying  maint  doors persons lug_boot safety  speed
# 0     vhigh  vhigh      2       2    small    low  unacc
# 1     vhigh  vhigh      2       2    small    med  unacc
# 2     vhigh  vhigh      2       2    small   high  unacc
# 3     vhigh  vhigh      2       2      med    low  unacc
# 4     vhigh  vhigh      2       2      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
cursor.execute('select buying,count(buying) from cardataset.cars group by buying')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %%
cursor.execute('select * from cardataset.cars where doors=4')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute('select count(*) from cardataset.cars where doors=4')

# %%
cursor.fetchall()
# Out:
# [(432,)]

# %%
cursor.execute('select count(*) from cardataset.cars where doors=2')

# %%
cursor.fetchall()
# Out:
# [(432,)]

# %%
cursor.execute('use cardataset')

# %%
cursor.execute('select distinct doors from cardataset.cars')

# %%
cursor.fetchall()
# Out:
# [('2',), ('3',), ('4',), ('5more',)]

# %%
cursor.execute('select * from cardataset.cars where not doors=2 and not doors=3 and not doors=4')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '5more', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '5more', '4', 'big', 'low', 'unacc'),
# ...

# %%
cursor.execute('select count(*) from cardataset.cars where not doors=2 and not doors=3 and not doors=4')
cursor.fetchall()
# Out:
# [(432,)]

# %%
cursor.execute('update cardataset.cars set doors=8 where doors=2')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Truncated incorrect DOUBLE value: '5more'
#
# During handling of the above exception, another exception occurred:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-12-82afec0125f0> in <module>
# ----> 1 cursor.execute('update cardataset.cars set doors=8 where doors=2')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...
